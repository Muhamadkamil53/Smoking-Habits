# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhamadkamil53/Smoking-Habits/blob/main/Smoking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# # Load the necessary packages
# import numpy as np
# import pandas as pd
# # import numpy as np
# # import pandas as pd
import pandas as pd
import numpy as np
import openpyxl as xl
from openpyxl import workbook, load_workbook

# %%
mydata = pd.read_csv('Smoking.csv')

# %%
mydata.describe()
# Out:
#              no.        Age  causes of smoking
# count  12.000000  12.000000                 0.0
# mean    6.500000  20.666667                 NaN
# std     3.605551   1.230915                 NaN
# min     1.000000  19.000000                 NaN
# 25%     3.750000  20.000000                 NaN
# 50%     6.500000  20.500000                 NaN
# 75%     9.250000  21.250000                 NaN
# max    12.000000  23.000000                 NaN

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

mydata.hist(figsize=(30,40))
plt.show()

# %%
mydata.hist(['Age'], figsize=(30,40))
plt.show()

# %%
import seaborn as sns

sns.boxplot(x="Gender", y="Age", data=mydata)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   no.                 12 non-null     int64
#  1   Name                12 non-null     object
#  2   Gender              12 non-null     object
#  3   Age                 12 non-null     int64
#  4   Address             12 non-null     object
#  5   Smoking Habits      12 non-null     object
#  6   causes of smoking   0 non-null      float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 800.0+ bytes

# %%
pd.crosstab(mydata['Smoking Habits'],mydata['Gender'] )
# Out:
# Gender          female  male
# Smoking Habits
# no                   3     5
# yes                  0     4

# %%
pd.crosstab(mydata['Smoking Habits'],mydata['Age'] )
# Out:
# Age             19  20  21  22  23
# Smoking Habits
# no               2   3   3   0   0
# yes              0   1   0   2   1

# %%
sns.countplot(x="Smoking Habits", hue="Gender", data=mydata)
# Out:
# <AxesSubplot:xlabel='Smoking Habits', ylabel='count'>

# %%
pd.pivot_table(mydata, index=['Smoking Habits', 'Gender'],
                     columns=[ 'Age'], aggfunc=len)
# Out:
#                       Address                     Name                      \
# Age                        19   20   21   22   23   19   20   21   22   23
# Smoking Habits Gender
# no             female     1.0  1.0  1.0  NaN  NaN  1.0  1.0  1.0  NaN  NaN
#                male       1.0  2.0  2.0  NaN  NaN  1.0  2.0  2.0  NaN  NaN
# yes            male       NaN  1.0  NaN  2.0  1.0  NaN  1.0  NaN  2.0  1.0
#
#                       causes of smoking                       no.            \
# Age                                   19   20   21   22   23   19   20   21
# Smoking Habits Gender
# no             female                1.0  1.0  1.0  NaN  NaN  1.0  1.0  1.0
#                male                  1.0  2.0  2.0  NaN  NaN  1.0  2.0  2.0
# yes            male                  NaN  1.0  NaN  2.0  1.0  NaN  1.0  NaN
#
#
# Age                     22   23
# Smoking Habits Gender
# no             female  NaN  NaN
#                male    NaN  NaN
# yes            male    2.0  1.0

# %%
pd.pivot_table(mydata,'Age', index=['Smoking Habits', 'Gender'],
                     columns=[ 'Address'])
# Out:
# Address                arbil  sulaymanyah
# Smoking Habits Gender
# no             female    NaN    20.000000
#                male     19.5    20.666667
# yes            male      NaN    21.750000

# %%
sns.pairplot(mydata)

# %%
mydata['Age'].std()
# Out:
# 1.2309149097933274

# %%
mydata['Age'].mean()
# Out:
# 20.666666666666668

# %%
mydata.hist(by='Gender',column = 'Age')
# Out:
# array([<AxesSubplot:title={'center':'female'}>,
#        <AxesSubplot:title={'center':'male'}>], dtype=object)

# %%
mydata.hist(by='Gender',column = 'Smoking Habits')
# Out:
# array([<AxesSubplot:title={'center':'female'}>,
#        <AxesSubplot:title={'center':'male'}>], dtype=object)

# %%
mydata.hist(by='Gender',column = 'Address')
# Out:
# array([<AxesSubplot:title={'center':'female'}>,
#        <AxesSubplot:title={'center':'male'}>], dtype=object)

# %%
mydata.hist(by='Smoking Habits',column = 'Address', figsize=(20,30))
# Out:
# array([<AxesSubplot:title={'center':'no'}>,
#        <AxesSubplot:title={'center':'yes'}>], dtype=object)

# %%
corr = mydata.corr()
corr
# Out:
#                          no.       Age  causes of smoking
# no.                 1.000000 -0.266288                 NaN
# Age                -0.266288  1.000000                 NaN
# causes of smoking        NaN       NaN                 NaN

# %%
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>
